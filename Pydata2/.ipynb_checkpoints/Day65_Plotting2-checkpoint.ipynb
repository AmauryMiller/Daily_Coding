# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from datetime import datetime

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = pd.read_csv('examples/spx.csv', index_col=0, parse_dates=True)

# %%
spx = data['SPX']

# %%
spx.plot(ax=ax, style='k-')
# Out:
# <AxesSubplot:>

# %%
crisis_data= [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy'),
    
]

# %%
for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='black', headwidth=4, width=2,
                                headlenght=4),
               horizontalalignment='left', verticalalignment='top')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-5f0590bb1858> in <module>
#       4                 arrowprops=dict(facecolor='black', headwidth=4, width=2,
#       5                                 headlenght=4),
# ----> 6                horizontalalignment='left', verticalalignment='top')
#
# ~\Miniconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     313                 f"for the old name will be dropped %(removal)s.")
#     314             kwargs[new] = kwargs.pop(old)
# --> 315         return func(*args, **kwargs)
#     316
#     317     # wrapper() must keep the same documented signature as func(): if we
#
# ~\Miniconda3\lib\site-packages\matplotlib\axes\_axes.py in annotate(self, text, xy, *args, **kwargs)
#     771     @docstring.dedent_interpd
#     772     def annotate(self, text, xy, *args, **kwargs):
# --> 773         a = mtext.Annotation(text, xy, *args, **kwargs)
#     774         a.set_transform(mtransforms.IdentityTransform())
#     775         if 'clip_on' in kwargs:
#
# ~\Miniconda3\lib\site-packages\matplotlib\text.py in __init__(self, text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#    1737                         'width', 'headwidth', 'headlength', 'shrink', 'frac']:
#    1738                     arrowprops.pop(key, None)
# -> 1739             self.arrow_patch = FancyArrowPatch((0, 0), (1, 1), **arrowprops)
#    1740         else:
#    1741             self.arrow_patch = None
#
# ~\Miniconda3\lib\site-packages\matplotlib\patches.py in __init__(self, posA, posB, path, arrowstyle, connectionstyle, patchA, patchB, shrinkA, shrinkB, mutation_scale, mutation_aspect, dpi_cor, **kwargs)
#    3928         kwargs.setdefault("capstyle", "round")
#    3929
# -> 3930         Patch.__init__(self, **kwargs)
#    3931
#    3932         if posA is not None and posB is not None and path is None:
#
# ~\Miniconda3\lib\site-packages\matplotlib\patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      93
#      94         if len(kwargs):
# ---> 95             self.update(kwargs)
#      96
#      97     def get_verts(self):
#
# ~\Miniconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'FancyArrowPatch' object has no property 'headlenght'

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
                   color='g', alpha=0.5)

# %%
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)
