# %%
import numpy as  np
import pandas as pd
import matplotlib.pyplot as plt

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))

# %%
s.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
                  columns=['A', 'B', 'C', 'D'],
                  index=np.arange(0, 100, 10))

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
# %matplotlib notebook

# %%
fig, axes = plt.subplots(2, 1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))

# %%
data.plot.bar(ax=axes[0], color='k', alpha=0.7)
# Out:
# <AxesSubplot:>

# %%
data.plot.barh(ax=axes[1], color='k', alpha=0.7)
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(6, 4),
                  index=['one', 'two', 'three', 'four', 'five', 'six'],
                  columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))

# %%
df
# Out:
# Genus         A         B         C         D
# one    0.840719  0.327708  0.542376  0.951527
# two    0.754776  0.370345  0.028629  0.430060
# three  0.193935  0.467445  0.999825  0.912809
# four   0.835442  0.150119  0.776543  0.526800
# five   0.240974  0.942528  0.392015  0.692634
# six    0.647749  0.359725  0.092827  0.580629

# %%
df.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
df.plot.barh(stacked=True, alpha=0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>
